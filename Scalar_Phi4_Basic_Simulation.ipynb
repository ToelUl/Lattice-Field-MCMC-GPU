# %%
from lattice_field_mcmc import ScalarPhi4Model2D
import torch

# %%
L_size = 32
kappas = torch.linspace(0.22, 0.3, 64)
lambda_val = 0.02
chains = 10

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

phi4_sampler = ScalarPhi4Model2D(
    L=L_size,
    kappa=kappas.to(device),
    lambda_=lambda_val,
    n_chains=chains,
    proposal_width=0.4,
    target_acceptance_rate=0.5,
    tune_interval=50,
    tuning_strength=0.2,
    device=device,
    use_amp=True,
    pt_enabled=True
)

samples = phi4_sampler.forward(
    n_sweeps=3000,
    n_therm=10000,
    decorrelate=10,
    pt_interval=2
)

print(f"Simulation complete. Sample tensor shape: {samples.shape}")
# Out:
# Initialized ScalarLatticeSampler2D on device: cuda
#  L=32, BatchSize=64, ChainsPerKappa=10, AMP=True, PT=True, LargeSim=False
# Proposal width tuning enabled: target_rate=0.5, interval=50
# Starting simulation: 10000 thermalization sweeps, 3000 production sweeps.
# Proposal width tuning is ENABLED.
#   [Tuning] Avg Acc Rate: 0.929 -> Avg Proposal Width: 0.434
#   [Tuning] Avg Acc Rate: 0.935 -> Avg Proposal Width: 0.472
#   [Tuning] Avg Acc Rate: 0.933 -> Avg Proposal Width: 0.513
#   [Tuning] Avg Acc Rate: 0.927 -> Avg Proposal Width: 0.557
#   [Tuning] Avg Acc Rate: 0.921 -> Avg Proposal Width: 0.604
#   [Tuning] Avg Acc Rate: 0.914 -> Avg Proposal Width: 0.654
#   [Tuning] Avg Acc Rate: 0.907 -> Avg Proposal Width: 0.707
#   [Tuning] Avg Acc Rate: 0.899 -> Avg Proposal Width: 0.763
#   [Tuning] Avg Acc Rate: 0.891 -> Avg Proposal Width: 0.823
#   [Tuning] Avg Acc Rate: 0.882 -> Avg Proposal Width: 0.886
#   [Tuning] Avg Acc Rate: 0.873 -> Avg Proposal Width: 0.952
#   [Tuning] Avg Acc Rate: 0.863 -> Avg Proposal Width: 1.021
#   [Tuning] Avg Acc Rate: 0.853 -> Avg Proposal Width: 1.093
#   [Tuning] Avg Acc Rate: 0.842 -> Avg Proposal Width: 1.167
#   [Tuning] Avg Acc Rate: 0.831 -> Avg Proposal Width: 1.245
#   [Tuning] Avg Acc Rate: 0.820 -> Avg Proposal Width: 1.324
#   [Tuning] Avg Acc Rate: 0.808 -> Avg Proposal Width: 1.406
#   [Tuning] Avg Acc Rate: 0.797 -> Avg Proposal Width: 1.490
#   [Tuning] Avg Acc Rate: 0.785 -> Avg Proposal Width: 1.574
#   [Tuning] Avg Acc Rate: 0.773 -> Avg Proposal Width: 1.660
#   [Tuning] Avg Acc Rate: 0.761 -> Avg Proposal Width: 1.747
#   [Tuning] Avg Acc Rate: 0.749 -> Avg Proposal Width: 1.834
#   [Tuning] Avg Acc Rate: 0.737 -> Avg Proposal Width: 1.921
#   [Tuning] Avg Acc Rate: 0.726 -> Avg Proposal Width: 2.008
#   [Tuning] Avg Acc Rate: 0.714 -> Avg Proposal Width: 2.094
#   [Tuning] Avg Acc Rate: 0.703 -> Avg Proposal Width: 2.179
#   [Tuning] Avg Acc Rate: 0.692 -> Avg Proposal Width: 2.263
#   [Tuning] Avg Acc Rate: 0.681 -> Avg Proposal Width: 2.345
#   [Tuning] Avg Acc Rate: 0.670 -> Avg Proposal Width: 2.425
#   [Tuning] Avg Acc Rate: 0.660 -> Avg Proposal Width: 2.503
#   [Tuning] Avg Acc Rate: 0.650 -> Avg Proposal Width: 2.578
#   [Tuning] Avg Acc Rate: 0.641 -> Avg Proposal Width: 2.651
#   [Tuning] Avg Acc Rate: 0.632 -> Avg Proposal Width: 2.721
#   [Tuning] Avg Acc Rate: 0.624 -> Avg Proposal Width: 2.789
#   [Tuning] Avg Acc Rate: 0.616 -> Avg Proposal Width: 2.854
#   [Tuning] Avg Acc Rate: 0.608 -> Avg Proposal Width: 2.916
#   [Tuning] Avg Acc Rate: 0.601 -> Avg Proposal Width: 2.975
#   [Tuning] Avg Acc Rate: 0.594 -> Avg Proposal Width: 3.032
#   [Tuning] Avg Acc Rate: 0.588 -> Avg Proposal Width: 3.085
#   [Tuning] Avg Acc Rate: 0.582 -> Avg Proposal Width: 3.136
#   [Tuning] Avg Acc Rate: 0.576 -> Avg Proposal Width: 3.184
#   [Tuning] Avg Acc Rate: 0.571 -> Avg Proposal Width: 3.230
#   [Tuning] Avg Acc Rate: 0.566 -> Avg Proposal Width: 3.273
#   [Tuning] Avg Acc Rate: 0.562 -> Avg Proposal Width: 3.313
#   [Tuning] Avg Acc Rate: 0.557 -> Avg Proposal Width: 3.351
#   [Tuning] Avg Acc Rate: 0.553 -> Avg Proposal Width: 3.387
#   [Tuning] Avg Acc Rate: 0.549 -> Avg Proposal Width: 3.421
#   [Tuning] Avg Acc Rate: 0.546 -> Avg Proposal Width: 3.452
#   [Tuning] Avg Acc Rate: 0.542 -> Avg Proposal Width: 3.482
#   [Tuning] Avg Acc Rate: 0.540 -> Avg Proposal Width: 3.509
#   [Tuning] Avg Acc Rate: 0.537 -> Avg Proposal Width: 3.535
#   [Tuning] Avg Acc Rate: 0.534 -> Avg Proposal Width: 3.560
#   [Tuning] Avg Acc Rate: 0.532 -> Avg Proposal Width: 3.582
#   [Tuning] Avg Acc Rate: 0.530 -> Avg Proposal Width: 3.604
#   [Tuning] Avg Acc Rate: 0.528 -> Avg Proposal Width: 3.624
#   [Tuning] Avg Acc Rate: 0.525 -> Avg Proposal Width: 3.642
#   [Tuning] Avg Acc Rate: 0.524 -> Avg Proposal Width: 3.660
#   [Tuning] Avg Acc Rate: 0.522 -> Avg Proposal Width: 3.676
#   [Tuning] Avg Acc Rate: 0.520 -> Avg Proposal Width: 3.691
#   [Tuning] Avg Acc Rate: 0.519 -> Avg Proposal Width: 3.705
#   [Tuning] Avg Acc Rate: 0.517 -> Avg Proposal Width: 3.718
#   [Tuning] Avg Acc Rate: 0.516 -> Avg Proposal Width: 3.730
#   [Tuning] Avg Acc Rate: 0.515 -> Avg Proposal Width: 3.742
#   [Tuning] Avg Acc Rate: 0.514 -> Avg Proposal Width: 3.752
#   [Tuning] Avg Acc Rate: 0.513 -> Avg Proposal Width: 3.762
#   [Tuning] Avg Acc Rate: 0.512 -> Avg Proposal Width: 3.771
#   [Tuning] Avg Acc Rate: 0.511 -> Avg Proposal Width: 3.780
#   [Tuning] Avg Acc Rate: 0.510 -> Avg Proposal Width: 3.788
#   [Tuning] Avg Acc Rate: 0.510 -> Avg Proposal Width: 3.795
#   [Tuning] Avg Acc Rate: 0.509 -> Avg Proposal Width: 3.802
#   [Tuning] Avg Acc Rate: 0.509 -> Avg Proposal Width: 3.809
#   [Tuning] Avg Acc Rate: 0.508 -> Avg Proposal Width: 3.815
#   [Tuning] Avg Acc Rate: 0.507 -> Avg Proposal Width: 3.820
#   [Tuning] Avg Acc Rate: 0.506 -> Avg Proposal Width: 3.825
#   [Tuning] Avg Acc Rate: 0.506 -> Avg Proposal Width: 3.830
#   [Tuning] Avg Acc Rate: 0.506 -> Avg Proposal Width: 3.834
#   [Tuning] Avg Acc Rate: 0.505 -> Avg Proposal Width: 3.838
#   [Tuning] Avg Acc Rate: 0.505 -> Avg Proposal Width: 3.842
#   [Tuning] Avg Acc Rate: 0.504 -> Avg Proposal Width: 3.846
#   [Tuning] Avg Acc Rate: 0.504 -> Avg Proposal Width: 3.849
#   [Tuning] Avg Acc Rate: 0.504 -> Avg Proposal Width: 3.852
#   [Tuning] Avg Acc Rate: 0.503 -> Avg Proposal Width: 3.855
#   [Tuning] Avg Acc Rate: 0.504 -> Avg Proposal Width: 3.857
#   [Tuning] Avg Acc Rate: 0.503 -> Avg Proposal Width: 3.860
#   [Tuning] Avg Acc Rate: 0.503 -> Avg Proposal Width: 3.862
#   [Tuning] Avg Acc Rate: 0.503 -> Avg Proposal Width: 3.864
#   [Tuning] Avg Acc Rate: 0.502 -> Avg Proposal Width: 3.866
#   [Tuning] Avg Acc Rate: 0.502 -> Avg Proposal Width: 3.868
#   [Tuning] Avg Acc Rate: 0.502 -> Avg Proposal Width: 3.870
#   [Tuning] Avg Acc Rate: 0.502 -> Avg Proposal Width: 3.871
#   [Tuning] Avg Acc Rate: 0.502 -> Avg Proposal Width: 3.873
#   [Tuning] Avg Acc Rate: 0.502 -> Avg Proposal Width: 3.874
#   [Tuning] Avg Acc Rate: 0.502 -> Avg Proposal Width: 3.875
#   [Tuning] Avg Acc Rate: 0.502 -> Avg Proposal Width: 3.877
#   [Tuning] Avg Acc Rate: 0.502 -> Avg Proposal Width: 3.878
#   [Tuning] Avg Acc Rate: 0.501 -> Avg Proposal Width: 3.879
#   [Tuning] Avg Acc Rate: 0.501 -> Avg Proposal Width: 3.880
#   [Tuning] Avg Acc Rate: 0.501 -> Avg Proposal Width: 3.881
#   [Tuning] Avg Acc Rate: 0.501 -> Avg Proposal Width: 3.881
#   [Tuning] Avg Acc Rate: 0.501 -> Avg Proposal Width: 3.882
#   [Tuning] Avg Acc Rate: 0.501 -> Avg Proposal Width: 3.883
#   [Tuning] Avg Acc Rate: 0.501 -> Avg Proposal Width: 3.883
#   [Tuning] Avg Acc Rate: 0.501 -> Avg Proposal Width: 3.884
#   [Tuning] Avg Acc Rate: 0.501 -> Avg Proposal Width: 3.884
#   [Tuning] Avg Acc Rate: 0.501 -> Avg Proposal Width: 3.885
#   [Tuning] Avg Acc Rate: 0.501 -> Avg Proposal Width: 3.885
#   [Tuning] Avg Acc Rate: 0.501 -> Avg Proposal Width: 3.886
#   [Tuning] Avg Acc Rate: 0.501 -> Avg Proposal Width: 3.886
#   [Tuning] Avg Acc Rate: 0.501 -> Avg Proposal Width: 3.887
#   [Tuning] Avg Acc Rate: 0.501 -> Avg Proposal Width: 3.887
#   [Tuning] Avg Acc Rate: 0.500 -> Avg Proposal Width: 3.887
#   [Tuning] Avg Acc Rate: 0.500 -> Avg Proposal Width: 3.888
#   [Tuning] Avg Acc Rate: 0.500 -> Avg Proposal Width: 3.888
#   [Tuning] Avg Acc Rate: 0.500 -> Avg Proposal Width: 3.888
#   [Tuning] Avg Acc Rate: 0.500 -> Avg Proposal Width: 3.889
#   [Tuning] Avg Acc Rate: 0.501 -> Avg Proposal Width: 3.889
#   [Tuning] Avg Acc Rate: 0.500 -> Avg Proposal Width: 3.889
#   [Tuning] Avg Acc Rate: 0.500 -> Avg Proposal Width: 3.889
#   [Tuning] Avg Acc Rate: 0.500 -> Avg Proposal Width: 3.890
#   [Tuning] Avg Acc Rate: 0.500 -> Avg Proposal Width: 3.890
#   [Tuning] Avg Acc Rate: 0.500 -> Avg Proposal Width: 3.890
#   [Tuning] Avg Acc Rate: 0.500 -> Avg Proposal Width: 3.890
#   [Tuning] Avg Acc Rate: 0.500 -> Avg Proposal Width: 3.890
#   [Tuning] Avg Acc Rate: 0.500 -> Avg Proposal Width: 3.890
#   [Tuning] Avg Acc Rate: 0.500 -> Avg Proposal Width: 3.891
#   [Tuning] Avg Acc Rate: 0.500 -> Avg Proposal Width: 3.891
#   [Tuning] Avg Acc Rate: 0.500 -> Avg Proposal Width: 3.891
#   [Tuning] Avg Acc Rate: 0.500 -> Avg Proposal Width: 3.891
#   [Tuning] Avg Acc Rate: 0.500 -> Avg Proposal Width: 3.891
#   [Tuning] Avg Acc Rate: 0.500 -> Avg Proposal Width: 3.891
#   [Tuning] Avg Acc Rate: 0.500 -> Avg Proposal Width: 3.891
#   [Tuning] Avg Acc Rate: 0.500 -> Avg Proposal Width: 3.891
#   [Tuning] Avg Acc Rate: 0.500 -> Avg Proposal Width: 3.891
#   [Tuning] Avg Acc Rate: 0.500 -> Avg Proposal Width: 3.891
#   [Tuning] Avg Acc Rate: 0.500 -> Avg Proposal Width: 3.891
#   [Tuning] Avg Acc Rate: 0.500 -> Avg Proposal Width: 3.891
#   [Tuning] Avg Acc Rate: 0.500 -> Avg Proposal Width: 3.891
#   [Tuning] Avg Acc Rate: 0.500 -> Avg Proposal Width: 3.892
#   [Tuning] Avg Acc Rate: 0.500 -> Avg Proposal Width: 3.891
#   [Tuning] Avg Acc Rate: 0.500 -> Avg Proposal Width: 3.892
#   [Tuning] Avg Acc Rate: 0.500 -> Avg Proposal Width: 3.892
#   [Tuning] Avg Acc Rate: 0.500 -> Avg Proposal Width: 3.892
#   [Tuning] Avg Acc Rate: 0.500 -> Avg Proposal Width: 3.891
#   [Tuning] Avg Acc Rate: 0.500 -> Avg Proposal Width: 3.891
#   [Tuning] Avg Acc Rate: 0.500 -> Avg Proposal Width: 3.892
#   [Tuning] Avg Acc Rate: 0.500 -> Avg Proposal Width: 3.892
#   [Tuning] Avg Acc Rate: 0.500 -> Avg Proposal Width: 3.892
#   [Tuning] Avg Acc Rate: 0.500 -> Avg Proposal Width: 3.892
#   [Tuning] Avg Acc Rate: 0.500 -> Avg Proposal Width: 3.892
#   [Tuning] Avg Acc Rate: 0.500 -> Avg Proposal Width: 3.892
#   [Tuning] Avg Acc Rate: 0.500 -> Avg Proposal Width: 3.892
#   [Tuning] Avg Acc Rate: 0.500 -> Avg Proposal Width: 3.892
#   [Tuning] Avg Acc Rate: 0.500 -> Avg Proposal Width: 3.892
#   [Tuning] Avg Acc Rate: 0.500 -> Avg Proposal Width: 3.892
#   [Tuning] Avg Acc Rate: 0.500 -> Avg Proposal Width: 3.892
#   [Tuning] Avg Acc Rate: 0.500 -> Avg Proposal Width: 3.892
#   [Tuning] Avg Acc Rate: 0.500 -> Avg Proposal Width: 3.892
#   [Tuning] Avg Acc Rate: 0.500 -> Avg Proposal Width: 3.892
#   [Tuning] Avg Acc Rate: 0.500 -> Avg Proposal Width: 3.891
#   [Tuning] Avg Acc Rate: 0.500 -> Avg Proposal Width: 3.892
#   [Tuning] Avg Acc Rate: 0.500 -> Avg Proposal Width: 3.892
#   [Tuning] Avg Acc Rate: 0.500 -> Avg Proposal Width: 3.892
#   [Tuning] Avg Acc Rate: 0.500 -> Avg Proposal Width: 3.892
#   [Tuning] Avg Acc Rate: 0.500 -> Avg Proposal Width: 3.892
#   [Tuning] Avg Acc Rate: 0.500 -> Avg Proposal Width: 3.892
#   [Tuning] Avg Acc Rate: 0.500 -> Avg Proposal Width: 3.892
#   [Tuning] Avg Acc Rate: 0.500 -> Avg Proposal Width: 3.892
#   [Tuning] Avg Acc Rate: 0.500 -> Avg Proposal Width: 3.892
#   [Tuning] Avg Acc Rate: 0.500 -> Avg Proposal Width: 3.892
#   [Tuning] Avg Acc Rate: 0.500 -> Avg Proposal Width: 3.892
#   [Tuning] Avg Acc Rate: 0.500 -> Avg Proposal Width: 3.892
#   [Tuning] Avg Acc Rate: 0.500 -> Avg Proposal Width: 3.892
#   [Tuning] Avg Acc Rate: 0.500 -> Avg Proposal Width: 3.892
#   [Tuning] Avg Acc Rate: 0.500 -> Avg Proposal Width: 3.892
#   [Tuning] Avg Acc Rate: 0.500 -> Avg Proposal Width: 3.892
#   [Tuning] Avg Acc Rate: 0.500 -> Avg Proposal Width: 3.892
#   [Tuning] Avg Acc Rate: 0.500 -> Avg Proposal Width: 3.892
#   [Tuning] Avg Acc Rate: 0.500 -> Avg Proposal Width: 3.892
#   [Tuning] Avg Acc Rate: 0.500 -> Avg Proposal Width: 3.892
#   [Tuning] Avg Acc Rate: 0.500 -> Avg Proposal Width: 3.892
#   [Tuning] Avg Acc Rate: 0.500 -> Avg Proposal Width: 3.892
#   [Tuning] Avg Acc Rate: 0.500 -> Avg Proposal Width: 3.892
#   [Tuning] Avg Acc Rate: 0.500 -> Avg Proposal Width: 3.892
#   [Tuning] Avg Acc Rate: 0.500 -> Avg Proposal Width: 3.892
#   [Tuning] Avg Acc Rate: 0.500 -> Avg Proposal Width: 3.892
#   [Tuning] Avg Acc Rate: 0.500 -> Avg Proposal Width: 3.892
#   [Tuning] Avg Acc Rate: 0.500 -> Avg Proposal Width: 3.892
#   [Tuning] Avg Acc Rate: 0.500 -> Avg Proposal Width: 3.892
#   [Tuning] Avg Acc Rate: 0.500 -> Avg Proposal Width: 3.892
#   [Tuning] Avg Acc Rate: 0.500 -> Avg Proposal Width: 3.892
#   [Tuning] Avg Acc Rate: 0.500 -> Avg Proposal Width: 3.892
#   [Tuning] Avg Acc Rate: 0.500 -> Avg Proposal Width: 3.892
#   [Tuning] Avg Acc Rate: 0.500 -> Avg Proposal Width: 3.892
#   [Tuning] Avg Acc Rate: 0.500 -> Avg Proposal Width: 3.892
#   [Tuning] Avg Acc Rate: 0.500 -> Avg Proposal Width: 3.892
#   [Tuning] Avg Acc Rate: 0.500 -> Avg Proposal Width: 3.892
#   [Tuning] Avg Acc Rate: 0.500 -> Avg Proposal Width: 3.892
#   [Tuning] Avg Acc Rate: 0.500 -> Avg Proposal Width: 3.892
#   [Tuning] Avg Acc Rate: 0.500 -> Avg Proposal Width: 3.891
#   [Tuning] Avg Acc Rate: 0.500 -> Avg Proposal Width: 3.891
# Simulation finished. Collected 3000 samples per kappa.
# Simulation complete. Sample tensor shape: torch.Size([64, 3000, 32, 32])

# %%
magnetization = samples.mean(dim=(-1, -2))
chi = torch.abs(magnetization).var(dim=1).cpu().numpy()
avg_magnetization_per_kappa = torch.abs(magnetization).mean(dim=1).cpu().numpy() # 在鏈和樣本維度上平均絕對值

import matplotlib.pyplot as plt

plt.figure(figsize=(8, 6))
plt.plot(kappas.cpu().numpy(), avg_magnetization_per_kappa, 'o-')
plt.xlabel("Kappa (κ)")
plt.ylabel("Average Magnetization |<M>|")
plt.title(f"Phi4 Model Magnetization vs. Kappa (L={L_size}, λ={lambda_val})")
plt.grid(True)
plt.show()

plt.figure(figsize=(8, 6))
plt.plot(kappas.cpu().numpy(), chi, 'o-')
plt.xlabel("Kappa (κ)")
plt.ylabel("Susceptibility χ")
plt.title(f"Phi4 Model Susceptibility vs. Kappa (L={L_size}, λ={lambda_val})")
plt.grid(True)
plt.show()
